# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaAltisheva/DataCon/blob/master/Copy_of_Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задание:
# Перед вами данные исследования токсичности наноматериалов.
# Это краткое описание баз данных с информациями о наноматериалах, их составе, физико-химических характеристиках, условиях проведения исследований нанотоксичности и данные по выживаемости клеток.
#
# ##Описание:
#
# material type, nanoparticle - химическая формула
#
# elements - некислородный элемент входящий в состав (причина - большинство материалов оксиды и металлы)
#
# electronegativity - электроотрицательность по Полингу
#
# ionic radius - ионный радиус элемента (исходя из степени окисления; если смесь степеней - среднее значение)
#
# core size - размер кристаллита (составной элемент наночастиц, который в принципе можно назвать элементарной ячейкой наночастиц)
#
# hydro size, diameter - гидродинамический диаметр частиц - диаметр частиц в растворе
#
# surface charge, zeta potential - дзета-потенциал или заряд поверхности
#
# surface area - площадь поверхности материала (измерено сорбцией азота)
#
# cell type, cells - два типа клеточных линий
#
# exposure dose, concentration, dose - финальная концентрация частиц в растворе с клетками
#
# number of atoms - ачевидно
#
# molecular weight - ачивидно
#
# topological polar surface area - дескриптор рассчитываемый из формулы
#
# a,b,c, alpha, beta, gamma - параметры кристаллической решетки
#
# density - плотность материала
#
# viability - выживаемость клеток
#
# type - тип (органика неорганика)
#
# coat - поверхностная модификация
#
# cell line / primary cells - тип клеток (клеточная линия или отобрано непосредственно из организма)
#
# human / animal - ачивидно
#
# animal - панятна
#
# cell morphology - тип ткани
#
# cell age - эмбриональные или зрелые
#
# cell organ / tissue - орган
#
# exposure time, time - время инкубации материала с клетками
#
# test - тип теста для оценки токсичности материалов
#
# test indicator - использованный реагент
#
# biochemical metrics - по чему оценивалась жизнеспособность
#
# interference test - проверка на то что другие реагенты не вмешивались в результаты
#
# colloidal stability - стабильны ли частицы в растворе
#
# positive control - наличие положительного контроля в тесте (тест демонстрирующий нормальный рост клеток)

# %%
# Импортируем все необходимые библиотеки
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Подгружаем два датасета
df1 = pd.read_excel('np_database_1.xlsx')
df2 = pd.read_excel('np_database_2.xlsx')

# %%
# Смотрим размеры датасетов
print('Размер первого набора данных', df1.shape)
print('Размер первого набора данных', df2.shape)
# Out:
# Размер первого набора данных (807, 13)
# Размер первого набора данных (1064, 16)

# %% [markdown]
# Количество столбцов и строк разное. Перед тем, как объединить эти датасеты, нужно уровнять количество столбцов. Найти зависимости и взаимосвязи данных.

# %% [markdown]
# #Начнем с приведения датасетов к аналогичному виду:
# - Удалим лишние столбцы
# - Заменим часть значений

# %% [markdown]
# Выведем списки всех заголовков

# %%
print('список заголовков первого датасета', df1.columns.ravel())
print('список заголовков второго датасета', df2.columns.ravel())
# Out:
# список заголовков первого датасета ['Unnamed: 0' 'Nanoparticle' 'Type: Organic (O)/inorganic (I)' 'coat'
#  'Diameter (nm)' 'Concentration μM' 'Zeta potential (mV)' 'Cells'
#  'Cell line (L)/primary cells (P)' 'Human(H)/Animal(A) cells'
#  'Cell age: embryonic (E), Adult (A)' 'Exposure time (h)'
#  '% Cell viability']
# список заголовков второго датасета ['Unnamed: 0' 'No' 'Year' 'Material' 'Type' 'Coat' 'Surface_Charge'
#  'Diameter (nm)' 'Cell_Type' 'Human_Animal' 'Cell_Age'
#  'Cell Line_Primary Cell' 'Time (hr)' 'Concentration (ug/ml)'
#  'Cell_Viability (%)' 'DOI']
# <ipython-input-182-0f27f8649ae9>:1: FutureWarning:
#
# Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#
# <ipython-input-182-0f27f8649ae9>:2: FutureWarning:
#
# Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.

# %% [markdown]
# На данном шаге мы установили, что лишние столбцы это: No, Year, DOI. Они есть в одном датасете, но отсутствуют в другом. Мы приняли решение их удалить.
# Во втором датасете мы переименовываем все колонки, делаем также как в первом.

# %%
# удаляем из второго датафрейма столбцы номер, год и DOI, остальные столбцы переименовываем, как в первом датасете
df2.drop(['No', 'Year', 'DOI'], axis=1, inplace=True)
df2.rename(columns={'Material':'Nanoparticle','Type':'Type: Organic (O)/inorganic (I)','Coat':'coat', 'Diameter (nm)': 'Diameter (nm)',
                    'Surface_Charge': 'Zeta potential (mV)', 'Cell_Type': 'Cells', 'Human_Animal': 'Human(H)/Animal(A) cells',
                    'Cell_Age': 'Cell age: embryonic (E), Adult (A)', 'Cell Line_Primary Cell': 'Cell line (L)/primary cells (P)', 'Time (hr)': 'Exposure time (h)',
                    'Concentration (ug/ml)': 'Concentration μM', 'Cell_Viability (%)': '% Cell viability'},inplace=True)
df2.head() # проверяем, получилось ли всё переименовать
# Out:
#    Unnamed: 0 Nanoparticle Type: Organic (O)/inorganic (I)     coat  \
# 0          92    IronOxide                               I  Dextran
# 1          93    IronOxide                               I  Dextran
# 2          94    IronOxide                               I  Dextran
# 3          95    IronOxide                               I  Dextran
# 4          96    IronOxide                               I  Dextran
#
#   Zeta potential (mV) Diameter (nm) Cells Human(H)/Animal(A) cells  \
# 0             unknown            18  VERO                        A
# 1             unknown            18  VERO                        A
# 2             unknown            18  VERO                        A
# 3             unknown            18  VERO                        A
# 4             unknown            18  VERO                        A
#
#   Cell age: embryonic (E), Adult (A) Cell line (L)/primary cells (P)  \
# 0                              Adult                               L
# 1                              Adult                               L
# 2                              Adult                               L
# 3                              Adult                               L
# 4                              Adult                               L
#
#    Exposure time (h) Concentration μM  % Cell viability
# 0                 24              100            102.00
# 1                 24              200            105.08
# 2                 24              300            100.00
# 3                 24              400            100.00
# 4                 24              500             80.00

# %%
# сравним теперь с первым датасетом
df1.head()
# Out:
#    Unnamed: 0 Nanoparticle Type: Organic (O)/inorganic (I) coat  \
# 0           9          CuO                               I  NaN
# 1          10          CuO                               I  NaN
# 2          11          CuO                               I  NaN
# 3          12          CuO                               I  NaN
# 4          13          CuO                               I  NaN
#
#    Diameter (nm)  Concentration μM  Zeta potential (mV) Cells  \
# 0          52.51          0.000035               -39.67  A549
# 1          52.51          0.000087               -39.67  A549
# 2          52.51          0.000174               -39.67  A549
# 3          52.51          0.000035               -39.67  A549
# 4          52.51          0.000087               -39.67  A549
#
#   Cell line (L)/primary cells (P) Human(H)/Animal(A) cells  \
# 0                               L                        H
# 1                               L                        H
# 2                               L                        H
# 3                               L                        H
# 4                               L                        H
#
#   Cell age: embryonic (E), Adult (A)  Exposure time (h)  % Cell viability
# 0                                  A                 24         74.587160
# 1                                  A                 24         66.055046
# 2                                  A                 24         48.165140
# 3                                  A                 24         84.713870
# 4                                  A                 24         68.672810

# %% [markdown]
# По столбцам датасеты стали идентичны. Но в первом датасете необходимо пересчитать значение Concentration μM и удалить значения '-' (если их не кретично много)

# %%
len(df2[df2['Concentration μM'] == '-']) # значений 112, принято решение их удалить
# Out:
# 112

# %% [markdown]
# Также поступаем со значениями в столбце Diameter (nm), где стоят '-'.

# %%
len(df2[df2['Diameter (nm)'] == '-'])
# Out:
# 114

# %% [markdown]
# Видим, что значение '-' встречается 112 раз из 1064. Заменить не получается, принимаем решение удалить данные строки и привести object к float. Это важно, поскольку дальше нам нужно будет работать с данными и строить графики

# %%
df2 = df2.loc[df2['Concentration μM'] != '-']

# %%
df2 = df2.loc[df2['Diameter (nm)'] != '-']

# %%
df2['Concentration μM'] = pd.to_numeric(df2['Concentration μM']) # переводим object в float
df2['Diameter (nm)'] = pd.to_numeric(df2['Diameter (nm)']) # переводим object в float

# %% [markdown]
# Проанализировав датасеты, приходим к решению пересчитать во втором датасете значения Concentration μM

# %%
df2.loc[df2['Nanoparticle'] == 'Au', 'Concentration μM'] = df2['Concentration μM'] / 196.97 * 1000
df2.loc[df2['Nanoparticle'] == 'CuO', 'Concentration μM'] = df2['Concentration μM'] / 79.55 * 1000
df2.loc[df2['Nanoparticle'] == 'IronOxide', 'Concentration μM'] = df2['Concentration μM'] / 159.69 * 1000
df2.loc[df2['Nanoparticle'] == 'Iron oxide', 'Concentration μM'] = df2['Concentration μM'] / 159.69 * 1000

# %% [markdown]
# Во втором датасете отличаются данные по колонке Cell age, изменим их.

# %%
# Во втором датасете заменим значения embryonic на E, а знаечния Аdult на А
df2.loc[df2['Cell age: embryonic (E), Adult (A)'] == 'Adult', 'Cell age: embryonic (E), Adult (A)'] = 'A'
df2.loc[df2['Cell age: embryonic (E), Adult (A)'] == 'Embryonic', 'Cell age: embryonic (E), Adult (A)'] = 'E'
df2.loc[df2['Cell age: embryonic (E), Adult (A)'] == 'Fetus', 'Cell age: embryonic (E), Adult (A)'] = 'F'

# %% [markdown]
# Заполним пропуски в колонке 'Zeta potential (mV)'
#
#
# Au − 24.4 ± 0.8 mV
#
# CuO − 28.6 ± 0.9 mV
#
# Iron oxyde −48.7 ± 0.4 mV

# %%
df1.loc[df1['Nanoparticle'] == 'Au', 'Zeta potential (mV)'] = -24.4
df1.loc[df1['Nanoparticle'] == 'CuO', 'Zeta potential (mV)'] = -28.6
df1.loc[df1['Nanoparticle'] == 'Cu2O', 'Zeta potential (mV)'] = 10.4
df1.loc[df1['Nanoparticle'] == 'IronOxide', 'Zeta potential (mV)'] = -48.7
df1.loc[df1['Nanoparticle'] == 'Iron oxide', 'Zeta potential (mV)'] = -48.7

df2.loc[df2['Nanoparticle'] == 'Au', 'Zeta potential (mV)'] = -24.4
df2.loc[df2['Nanoparticle'] == 'CuO', 'Zeta potential (mV)'] = -28.6
df2.loc[df2['Nanoparticle'] == 'Cu2O', 'Zeta potential (mV)'] = 10.4
df2.loc[df2['Nanoparticle'] == 'IronOxide', 'Zeta potential (mV)'] = -48.7
df2.loc[df2['Nanoparticle'] == 'Iron oxide', 'Zeta potential (mV)'] = -48.7

# %% [markdown]
# Предварительно объединим данные в одну таблицу

# %%
df3 = pd.concat([df1,df2]) # предварительное объединение данных для анализа

# %% [markdown]
# Было замечено, что Iron Oxide зачастую записывался в разном формате. Исправим это.

# %%
df3.loc[df3['Nanoparticle'] == 'Iron oxide', 'Nanoparticle'] = 'IronOxide'

# %%
df3.loc[df3['Nanoparticle'] == 'IronOxide', 'Nanoparticle'] = 'Fe2O3'

# %% [markdown]
# Переименуем все столбцы на более читаемый и удобный вид

# %%
df3.rename(columns={'Nanoparticle':'Material', 'Type: Organic (O)/inorganic (I)': 'Type','coat':'Coat', 'Human(H)/Animal(A) cells': 'body_cells',
                    'Cell age: embryonic (E), Adult (A)': 'Cell_Age', 'Exposure time (h)': 'Time (hr)'},inplace=True)

# %%
df3 # смотрим, какой датасет у нас получился
# Out:
#       Unnamed: 0 Material Type     Coat  Diameter (nm)  Concentration μM  \
# 0              9      CuO    I      NaN          52.51          0.000035
# 1             10      CuO    I      NaN          52.51          0.000087
# 2             11      CuO    I      NaN          52.51          0.000174
# 3             12      CuO    I      NaN          52.51          0.000035
# 4             13      CuO    I      NaN          52.51          0.000087
# ...          ...      ...  ...      ...            ...               ...
# 1059        3811       Au    I  Citrate           4.70        507.691527
# 1060        3816       Au    I  Citrate         270.00         25.384576
# 1061        3817       Au    I  Citrate         270.00         50.769153
# 1062        3818       Au    I  Citrate         270.00        507.691527
# 1063        3819       Au    I  Citrate         270.00       5076.915266
#
#      Zeta potential (mV)     Cells Cell line (L)/primary cells (P) body_cells  \
# 0                  -28.6      A549                               L          H
# 1                  -28.6      A549                               L          H
# 2                  -28.6      A549                               L          H
# 3                  -28.6      A549                               L          H
# 4                  -28.6      A549                               L          H
# ...                  ...       ...                             ...        ...
# 1059               -24.4  RAW264.7                               L          A
# 1060               -24.4  RAW264.7                               L          A
# 1061               -24.4  RAW264.7                               L          A
# 1062               -24.4  RAW264.7                               L          A
# 1063               -24.4  RAW264.7                               L          A
#
#      Cell_Age  Time (hr)  % Cell viability
# 0           A         24         74.587160
# 1           A         24         66.055046
# 2           A         24         48.165140
# 3           A         24         84.713870
# 4           A         24         68.672810
# ...       ...        ...               ...
# 1059        A         48         68.957000
# 1060        A         48         93.893000
# 1061        A         48         86.005000
# 1062        A         48         79.644000
# 1063        A         48         52.672000
#
# [1670 rows x 13 columns]

# %% [markdown]
# Проверяем, где у нас остались пустые значения

# %%
df3.isnull().sum() # проверяем, где у нас есть пустые значения
# Out:
# Unnamed: 0                           0
# Material                             0
# Type                                 0
# Coat                               237
# Diameter (nm)                        0
# Concentration μM                     0
# Zeta potential (mV)                  0
# Cells                                0
# Cell line (L)/primary cells (P)      0
# body_cells                           0
# Cell_Age                             0
# Time (hr)                            0
# % Cell viability                     0
# dtype: int64

# %%
# !pip install openpyxl # установка библиотеки для выгрузки данных
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)

# %%
df3.describe() # проведем описательный анализ численных значений
# Out:
#         Unnamed: 0  Diameter (nm)  Concentration μM    Time (hr)  \
# count  1670.000000    1670.000000      1.670000e+03  1670.000000
# mean   1502.222156      97.001078      2.182463e+02    37.697006
# std     993.687522     162.582483      7.777123e+02    30.674255
# min       9.000000       1.500000      3.681525e-31     1.000000
# 25%     631.250000      13.500000      3.817935e-05    24.000000
# 50%    1438.500000      30.000000      5.076915e+00    24.000000
# 75%    1978.750000     108.000000      1.257071e+02    48.000000
# max    3819.000000     957.000000      1.500000e+04   336.000000
#
#        % Cell viability
# count       1670.000000
# mean          81.446294
# std           33.354834
# min          -58.897640
# 25%           71.562000
# 50%           91.134000
# 75%           98.655642
# max          404.811700

# %% [markdown]
# Колонку Zeta нужно перевести в float. Но из-за значения 'Positive', которое встречается лишь 1 раз, это сделать не удается. Изменим это.

# %%
df3 = df3.loc[df3['Zeta potential (mV)'] != 'Positive']
df3['Zeta potential (mV)'] = pd.to_numeric(df3['Zeta potential (mV)']) # переводим к численным значениям

# %% [markdown]
# Построим общие гистограммы по следующим значениям: 'Diameter (nm)', 'Concentration μM', '% Cell viability', 'Zeta potential (mV)', 'Time (hr)'

# %%
numerical_features = ['Diameter (nm)', 'Concentration μM', '% Cell viability', 'Zeta potential (mV)', 'Time (hr)']
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 6))
axes = axes.flatten()

for i, feature in enumerate(numerical_features):
    sns.histplot(data=df3, x=feature, ax=axes[i], color='green')
    axes[i].set_title(f'Histplot of {feature}')

plt.tight_layout()
plt.show()

# %% [markdown]
# Аналогичным образом построим ящики с усами, чтобы проанализировать наличие выбросов

# %%
numerical_features = ['Diameter (nm)', 'Concentration μM', '% Cell viability', 'Zeta potential (mV)', 'Time (hr)']
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 6))
axes = axes.flatten()

for i, feature in enumerate(numerical_features):
    sns.boxplot(data=df3, x=feature, ax=axes[i], color='grey')
    axes[i].set_title(f'Boxplot of {feature}')

plt.tight_layout()
plt.show()

# %% [markdown]
# Видим, что есть ряд выбросов от которых стоило бы избавиться

# %%
df3 = df3.loc[df3['Diameter (nm)'] < 420]
df3 = df3.loc[df3['Concentration μM'] < 4000]
df3 = df3.loc[df3['% Cell viability'] < 300]
df3 = df3.loc[df3['Time (hr)'] < 200]

# %% [markdown]
# Заменим значения выживаемости более 100 на 100, а менее 0 на 0.

# %%
df3.loc[df3['% Cell viability'] > 100, '% Cell viability'] = 100
df3.loc[df3['% Cell viability'] < 0, '% Cell viability'] = 0

# %% [markdown]
# Также посмотрим на то, как зависит % Cell viability от Time (hr)

# %%
fig, ax = plt.subplots(figsize = (8,5)) # Инициализация графиков и его размеров
ax.scatter(df3['Time (hr)'], df3['% Cell viability'], color = 'red')
plt.title('График зависимости % Cell viability от Time (hr)')
plt.xlabel('Time (h)')
plt.ylabel('% Cell viability')
plt.show() #Вывод графика

# %% [markdown]
# Как мы можем заметить, над определенным значением времени выстраивается столбик из начений выживаемости, что свидетельствует о том что врем не единственный параметр, влияющий на выживаемость или оно совсем не влияет.

# %%
fig, ax = plt.subplots(figsize = (8,5)) # Инициализация графиков и его размеров
ax.scatter(df3['Diameter (nm)'], df3['% Cell viability'], color = 'indigo')
plt.title('График зависимости % Cell viability от Diameter (nm)')
plt.xlabel('Diameter (nm)')
plt.ylabel('% Cell viability')
plt.show() #Вывод графика

# %% [markdown]
# На данном графите мы снова видим вертикальные столбцы. Что снова говорит нам о том, что диаметр не едиственный влияющий на выживаемость фактор.

# %% [markdown]
# Заменим значения в столбце Coat, где - на no data

# %%
df3.loc[df3['Coat'] == ' ', 'Coat'] = 'No data'

# %% [markdown]
# Построим график зависимости Coat от количества встречающихся элементов. Видим, что очень много пропусков. Самые часто встречающиеся значения это PEI, Citrate and PVP

# %%
plt.figure(figsize=(20, 5))
ax = sns.countplot(data=df3, x='Coat',)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
plt.title('График зависимости Coat от количества встречающихся элементов.')
plt.show()

# %% [markdown]
# Построим график по материалам и посмотрим, какие в исследованиях применялись чаще всего.

# %%
# plt.figure(figsize=(10,5))
# ax = sns.countplot(data=df3, x='Material',)
# ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# plt.title('График зависимости материалов от частоты использования')
# plt.show()


colors = ( "orange", "cyan", "brown",
          "grey")
materials = ['CuO', 'Fe2O3', 'Cu2O', 'Au']
data = [len(df3[df3['Material'] == 'CuO']), len(df3[df3['Material'] == 'Fe2O3']), len(df3[df3['Material'] == 'Cu2O']), len(df3[df3['Material'] == 'Au'])]

wp = { 'linewidth' : 1, 'edgecolor' : "green" }

# Creating autocpt arguments
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)
explode = (0.1, 0.1, 0.1, 0.1)
fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts = ax.pie(data,
                                  autopct = lambda pct: func(pct, data),
                                  explode = explode,
                                  labels = materials,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="black"))

# Adding legend
ax.legend(wedges, materials,
          title ="Materials",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))

plt.setp(autotexts, size = 8, weight ="bold")
ax.set_title("Круговая диаграмма наноматериалов")

# show plot
plt.show()

# %% [markdown]
# Чаще всего исследования проводилиьс с использованием оксида железа

# %% [markdown]
# Построим общие боксплоты по каждому материалу в зависимости от концентрации

# %%
sns.boxplot(data = df3, x = 'Material', y = 'Concentration μM')
# Out:
# <Axes: xlabel='Material', ylabel='Concentration μM'>

# %% [markdown]
# Построим аналогичные бокспрлоты, отсекая данные по концентрации выше значения 1000

# %%
sns.boxplot(data = df3.loc[df3['Concentration μM'] < 1000], x = 'Material', y = 'Concentration μM')
# Out:
# <Axes: xlabel='Material', ylabel='Concentration μM'>

# %% [markdown]
# В данном случае можно сдлать вывод о высокой дисперсии данных по концентрации

# %% [markdown]
# Построим боксплоты для диаметров

# %%
sns.boxplot(data = df3, x = 'Material', y = 'Diameter (nm)')
# Out:
# <Axes: xlabel='Material', ylabel='Diameter (nm)'>

# %% [markdown]
# Теперь построим графики зависимости Diameter (nm) от Concentration μM для каждого элемента, а также общий график.

# %%
fig, ax = plt.subplots(figsize = (8,4)) # Инициализация графиков и его размеров
# Построим График зависимости Diameter (nm) от Concentration μM для CuO
df_cu = df3[df3['Material'] == 'CuO']
ax.scatter(df_cu['Diameter (nm)'], df_cu['Concentration μM'], color = 'red')
plt.title('График зависимости Concentration μM от Diameter (nm) для CuO')
plt.xlabel('Diameter (nm) ')
plt.ylabel('Concentration μM')
plt.legend(['CuO'])
plt.grid(True)
plt.show() #Вывод графика

fig, ax = plt.subplots(figsize = (8,4)) # Инициализация графиков и его размеров
# Построим График зависимости Diameter (nm) от Concentration μM для CuO
df_au = df3[df3['Material'] == 'Au']
ax.scatter(df_au['Diameter (nm)'], df_au['Concentration μM'], color = 'gold')
plt.title('График зависимости Concentration μM от Diameter (nm) для Au')
plt.xlabel('Diameter (nm) ')
plt.ylabel('Concentration μM')
plt.legend(['Au'])
plt.grid(True)
plt.show() #Вывод графика

fig, ax = plt.subplots(figsize = (8,4)) # Инициализация графиков и его размеров
# Построим График зависимости Diameter (nm) от Concentration μM для CuO
df_io = df3[df3['Material'] == 'Fe2O3']
ax.scatter(df_io['Diameter (nm)'], df_io['Concentration μM'], color = 'grey')
plt.title('График зависимости Concentration μM от Diameter (nm) для Fe2O3')
plt.xlabel('Diameter (nm) ')
plt.ylabel('Concentration μM')
plt.legend(['Iron Oxide'])
plt.grid(True)
plt.show() #Вывод графика

fig, ax = plt.subplots(figsize = (8,4)) # Инициализация графиков и его размеров
# Построим График зависимости Diameter (nm) от Concentration μM для CuO
df_cu2o = df3[df3['Material'] == 'Cu2O']
ax.scatter(df_cu2o['Diameter (nm)'], df_cu2o['Concentration μM'], color = 'pink')
plt.title('График зависимости Concentration μM от Diameter (nm) для Cu2O')
plt.xlabel('Diameter (nm) ')
plt.ylabel('Concentration μM')
plt.legend(['Cu2O'])
plt.grid(True)
plt.show() #Вывод графика

# %% [markdown]
# На основании данных графиков можно сделать выводы о том, что:
# Для CuO значением диаметра находятcя в узком диапазоне и не зависят от Concentration μM. Что говорит об устойчивости определенного значения диаметра.
#
# Для золота больше представлен диапазон концентраций от 0 до 500 и диаметр от 0 до 50.
#
# Для оксида железа больше всего представлен диапазон концентраций от 0 до 750 маленькому диаметру могут соответствовать разные концентрации.
#
# *судя по набору данных эксперимент проводился последовательным разбавлением.

# %% [markdown]
# Построим аналогичные графики для значений body cells (человек/животное)

# %%
fig, ax = plt.subplots(figsize =  (5,4)) # Инициализация графиков и его размеров
# Построим График зависимости Diameter (nm) от Concentration μM для CuO
df_io = df3[df3['body_cells'] == 'H']
ax.scatter(df_io['Diameter (nm)'], df_io['Concentration μM'], color = 'pink')
plt.title('График зависимости Concentration μM от Diameter (nm) для H(человека)')
plt.xlabel('Diameter (nm) ')
plt.ylabel('Concentration μM')
plt.legend(['Iron Oxide'])
plt.grid(True)
plt.show() #Вывод графика

fig, ax = plt.subplots(figsize =  (5,4)) # Инициализация графиков и его размеров
# Построим График зависимости Diameter (nm) от Concentration μM для CuO
df_cu2o = df3[df3['body_cells'] == 'A']
ax.scatter(df_cu2o['Diameter (nm)'], df_cu2o['Concentration μM'], color = 'brown')
plt.title('График зависимости Concentration μM от Diameter (nm) для A(животного)')
plt.xlabel('Diameter (nm) ')
plt.ylabel('Concentration μM')
plt.legend(['Cu2O'])
plt.grid(True)
plt.show() #Вывод графика

# %% [markdown]
# Как мы можем заметить, зависимость концентрации от диаметра для человека и животного схожи внешне, однако, для животного менее наполнены.

# %%
fig, ax = plt.subplots(figsize = (8,5)) # Инициализация графиков и его размеров
# Построим График зависимости Diameter (nm) от Concentration μM для CuO
# df_cu = df3[df3['Material'] == 'CuO']
ax.scatter(df_cu['Diameter (nm)'], df_cu['Concentration μM'], color = 'red')
ax.scatter(df_au['Diameter (nm)'], df_au['Concentration μM'], color = 'gold')
ax.scatter(df_io['Diameter (nm)'], df_io['Concentration μM'], color = 'blue')
ax.scatter(df_cu2o['Diameter (nm)'], df_cu2o['Concentration μM'], color = 'pink')
plt.title('График зависимости Concentration μM от Diameter (nm) для CuO, Au, IronOxide, Cu2O')
plt.xlabel('Diameter (nm) ')
plt.ylabel('Concentration μM')
plt.legend(['CuO', 'Au', 'Fe2O3', 'Cu2O'])
plt.grid(True)
plt.show() #Вывод графика

# %% [markdown]
# Как мы можем заметить по графику, образуются вертикальные столбы, что свидетельствует о том, что частице одного диаметра могут по разному влиять на концентрацию и существует ещё один влияющий признак

# %%
fig, ax = plt.subplots(figsize = (8,5)) # Инициализация графиков и его размеров
# Построим График зависимости Diameter (nm) от Concentration μM для CuO
# df_cu = df3[df3['Material'] == 'CuO']
ax.scatter(df_cu['Diameter (nm)'], df_cu['% Cell viability'], color = 'red')
ax.scatter(df_au['Diameter (nm)'], df_au['% Cell viability'], color = 'gold')
ax.scatter(df_io['Diameter (nm)'], df_io['% Cell viability'], color = 'blue')
ax.scatter(df_cu2o['Diameter (nm)'], df_cu2o['% Cell viability'], color = 'pink')
plt.title('График зависимости % Cell viability от Diameter (nm) для CuO, Au, IronOxide, Cu2O')
plt.xlabel('Diameter (nm) ')
plt.ylabel('% Cell viability')
plt.legend(['CuO', 'Au', 'Fe2O3', 'Cu2O'])
plt.grid(True)
plt.show() #Вывод графика

# %% [markdown]
# Если мы посмотрим на график, то можем заменить, что в большинстве высокая выживаемость у разных частиц наблюдается при маленьком диаметре, менее 50 нм. Однако, наоблюдаются снова вертикальные столбцы, которые могут свидетельствовать о наличии ещё одного влияющего признака.

# %%
fig, ax = plt.subplots(figsize =  (5,4)) # Инициализация графиков и его размеров
# Построим График зависимости Diameter (nm) от Concentration μM для CuO
df_io = df3[df3['body_cells'] == 'H']
ax.scatter(df_io['Diameter (nm)'], df_io['% Cell viability'], color = 'pink')
plt.title('График зависимости % Cell viability от Diameter (nm) для H(человека)')
plt.xlabel('Diameter (nm) ')
plt.ylabel('Concentration μM')
plt.legend(['Iron Oxide'])
plt.grid(True)
plt.show() #Вывод графика

fig, ax = plt.subplots(figsize =  (5,4)) # Инициализация графиков и его размеров
# Построим График зависимости Diameter (nm) от Concentration μM для CuO
df_cu2o = df3[df3['body_cells'] == 'A']
ax.scatter(df_cu2o['Diameter (nm)'], df_cu2o['% Cell viability'], color = 'brown')
plt.title('График зависимости % Cell viability от Diameter (nm) для A(животного)')
plt.xlabel('Diameter (nm) ')
plt.ylabel('Concentration μM')
plt.legend(['Cu2O'])
plt.grid(True)
plt.show() #Вывод графика

# %% [markdown]
# Как можем заметить, данных по животному меньше. Однако сохранение основной тенденции остается неизменным: чем мельше диаметр, тем больше выживаемость, но есть ещё один параметр.

# %% [markdown]
# Построим матрицу корелляции Пирсона. Чтобы понять, какие значения кореллируют между собой

# %%
df3.corr() # предварительно посмотрим табличные данные
# Out:
# <ipython-input-219-a277dd00f0e5>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                      Unnamed: 0  Diameter (nm)  Concentration μM  \
# Unnamed: 0             1.000000      -0.415527          0.031875
# Diameter (nm)         -0.415527       1.000000         -0.224164
# Concentration μM       0.031875      -0.224164          1.000000
# Zeta potential (mV)    0.271141      -0.194311         -0.092904
# Time (hr)              0.004590       0.204426         -0.112881
# % Cell viability       0.036157      -0.152415         -0.042808
#
#                      Zeta potential (mV)  Time (hr)  % Cell viability
# Unnamed: 0                      0.271141   0.004590          0.036157
# Diameter (nm)                  -0.194311   0.204426         -0.152415
# Concentration μM               -0.092904  -0.112881         -0.042808
# Zeta potential (mV)             1.000000  -0.114271         -0.145558
# Time (hr)                      -0.114271   1.000000         -0.147930
# % Cell viability               -0.145558  -0.147930          1.000000

# %%
corr = df3.corr()
f, ax = plt.subplots(figsize=(10, 8)) #создание графика и определение его размеров
cmap = sns.diverging_palette(220, 10, as_cmap=True) #создание палитры для корреляционного графика
sns.heatmap(corr,cmap=cmap, linewidths=.5, annot=True, fmt=".1f") # возьмем abs значение, чтобы нас не смущали отрицительные корреляции
plt.title('Матрица корелляции Пирсона')
#annot=True - вывод коэффициентов корреляции, fmt - число знаков после запятой, v - пределы, cmap - палитра, linewidth - толщина шрифта
# Out:
# <ipython-input-220-442d1619d390>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# Text(0.5, 1.0, 'Матрица корелляции Пирсона')

# %% [markdown]
# Поскольку корелляции не выявлено, принято решение построить матрицу на каждый материал

# %%
cuodf = df3[df3['Material'] == 'CuO']
cuodf.drop(['Zeta potential (mV)'], axis=1, inplace=True)
corr = cuodf.corr()
f, ax = plt.subplots(figsize=(10, 8)) #создание графика и определение его размеров
cmap = sns.diverging_palette(220, 10, as_cmap=True) #создание палитры для корреляционного графика
sns.heatmap(corr,cmap=cmap, linewidths=.5, annot=True, fmt=".1f") # возьмем abs значение, чтобы нас не смущали отрицительные корреляции
plt.title('Матрица корелляции Пирсона для CuO')
# Out:
# <ipython-input-221-4ce2e8c578ba>:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# Text(0.5, 1.0, 'Матрица корелляции Пирсона для CuO')

# %% [markdown]
# В данном случае может заметить отрицательную слабую корелляцию между Диаметром и Концентрацией (-0,3), между Диаметром и Временем (-0,4), между Диаметром и Выживаемостью клеток (0,2). Корелляция между Концентрацией и временем составила 0,1, что тоже слабый показатель. Зависимость концентрации от выживаемости клеток -0,3. То есть они изменяются обратно пропорционально друг другу. Зависимость Выживаемости клеток от времени -0,2.

# %%
audf = df3[df3['Material'] == 'Au']
audf.drop(['Zeta potential (mV)'], axis=1, inplace=True)
corr = audf.corr()
f, ax = plt.subplots(figsize=(10, 8)) #создание графика и определение его размеров
cmap = sns.diverging_palette(220, 10, as_cmap=True) #создание палитры для корреляционного графика
sns.heatmap(corr,cmap=cmap, linewidths=.5, annot=True, fmt=".1f") # возьмем abs значение, чтобы нас не смущали отрицительные корреляции
plt.title('Матрица корелляции Пирсона для Au')
# Out:
# <ipython-input-222-549be11e2a7b>:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# Text(0.5, 1.0, 'Матрица корелляции Пирсона для Au')

# %% [markdown]
# Тут мы видим обратную корелляцию между выживаемости клеток и Диаметром -0,2. Остальные показатели не дают возможности установить зависимость.

# %%
fedf = df3[df3['Material'] == 'Fe2O3']
fedf.drop(['Zeta potential (mV)'], axis=1, inplace=True)

corr = fedf.corr()
f, ax = plt.subplots(figsize=(10, 8)) #создание графика и определение его размеров
cmap = sns.diverging_palette(220, 10, as_cmap=True) #создание палитры для корреляционного графика
sns.heatmap(corr,cmap=cmap, linewidths=.5, annot=True, fmt=".1f") # возьмем abs значение, чтобы нас не смущали отрицительные корреляции
plt.title('Матрица корелляции Пирсона для Fe2O3')
# Out:
# <ipython-input-223-1f9cfc00b9b3>:4: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# Text(0.5, 1.0, 'Матрица корелляции Пирсона для Fe2O3')

# %% [markdown]
# Для Cu2O не удалось установить никаких зависимостей. (Это можно увидеть, развернув ячейку с кодом ниже)

# %%
cu20df = df3[df3['Material'] == 'Cu2O']
cu20df.drop(['Zeta potential (mV)'], axis=1, inplace=True)
cu20df.drop(['Diameter (nm)'], axis=1, inplace=True)
corr = cu20df.corr()
f, ax = plt.subplots(figsize=(10, 8)) #создание графика и определение его размеров
cmap = sns.diverging_palette(220, 10, as_cmap=True) #создание палитры для корреляционного графика
sns.heatmap(corr,cmap=cmap, linewidths=.5, annot=True, fmt=".1f") # возьмем abs значение, чтобы нас не смущали отрицительные корреляции
plt.title('Матрица корелляции Пирсона для Cu2O')
# Out:
# <ipython-input-224-bccb842625cd>:4: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# Text(0.5, 1.0, 'Матрица корелляции Пирсона для Cu2O')

# %% [markdown]
# Тут мы видим отрицательную корелляцию между концентрацией и выживаемостью.

# %% [markdown]
# Построим 3Д график зависимости % Cell viability, Diameter (nm), Concentration μM.

# %%
from mpl_toolkits.mplot3d import Axes3D

u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:10j]
x = df3['% Cell viability']
y = df3['Diameter (nm)']
z = df3['Concentration μM']
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)

# %% [markdown]
# Подводя итог, добавим все возможные графики зависимостей для дополнительной визуализации полученных результатов.

# %%
pd.plotting.scatter_matrix(df3, figsize=(12,12));

# %% [markdown]
# #Выводы:
# Скопление точек находится в области больоего выдивания, маленького диаметра и маленькой концентрации. Это говорит нам, что выживаемость растет при уменьшении концентрации и уменьшении диаметра!
#
# Также возможно проведение подобных аналогий, разделив организмы человека и животного при условии весомого отличия в составе анализируемых тканей.

# %% [markdown]
# #Заключение:
# Чаще всего исследования проводилиьс с использованием оксида железа
#
# Для CuO значением диаметра находятcя в узком диапазоне и не зависят от Concentration μM. Что говорит об устойчивости определенного значения диаметра.
#
# Для золота больше представлен диапазон концентраций от 0 до 500 и диаметр от 0 до 50.
#
# Для оксида железа больше всего представлен диапазон концентраций от 0 до 750 маленькому диаметру могут соответствовать разные концентрации.
#
# Графики зависимости выживаемости от диаметра для человека и животного схожи. Что говорит нам о возможном упрощении анализа в будущем.
#
# Выживаемость растет при уменьшении концентрации и уменьшении диаметра!
#
# *судя по набору данных эксперимент проводился последовательным разбавлением.

# %%
df3.to_csv(r'df3.csv') # выгрузка итогового датасета
